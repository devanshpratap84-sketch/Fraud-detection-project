# %% [markdown]
# # Fraud Detection System
# Run the complete project from `fraud_detection.py`.
#
# First place `creditcard.csv` inside the `data/` folder.

# %%
# !pip install -r requirements.txt
# %run fraud_detection.py
